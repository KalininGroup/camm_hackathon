# %% [markdown]
# <h1 align="center">CAMM Hackathon - Session 1</h1>
# <p align="left"><em>26 September 2025</em></p>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/KBForgeX/camm_hackathon/blob/k4my4r/docs/regressors/CAMM_Hackathon_1.ipynb)

# %% [markdown]
# **Data provenance** : The dataset aggregates measurements from a Dy–Er–Gd–Ho oxide wafer study in the CAMM by the Rack and Page groups

# %% [markdown]
# <h3>Goal: Feature → Target Prediction</h3>
#
#
# This notebook hands you a **clean, standardized dataset** and a minimal prep pipeline so you can build your own predictive models. Your goal is to use the provided **features** (materials/structure descriptors) to **predict a target property** (default: *Thermal Conductivity*). The notebook **stops at data preparation**—you will implement and compare models (e.g., linear models, trees, neural nets) using the prepared data.
#
# **What you’ll find here**
# - A tidy table with `x`, `y` wafer coordinates and a set of engineered features (numeric, aligned to the same grid, with units harmonized).
# - A simple example showing how to **select a target and features**, coerce to numeric, handle missing values (median imputation), and standardize inputs—ready for modeling.
# - You can swap the target and feature lists to explore different prediction tasks.
#
# **What you will do**
# - Choose a **target** (e.g., `Thermal Conductivity`) and a subset of **features** you think are predictive.
# - Train any models you like (sklearn, PyTorch, etc.) on the **prepared arrays**.
# - Report basic metrics (RMSE, MAE, $R^2$) and, if useful, visualize predictions on the wafer grid using `x`, `y`.

# %% [markdown]
# #Data Preparation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1BSZ3YyTw6dqELnL9qpfV8V5wVrbA-BPz/view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BSZ3YyTw6dqELnL9qpfV8V5wVrbA-BPz
# To: /content/ReZrO_data.csv
# 100% 513k/513k [00:00<00:00, 138MB/s]

# %%
path = "/content/ReZrO_data.csv"   # update if path differs
df = pd.read_csv(path)

# %% [markdown]
# Let's see what all properties we have in the dataset

# %%
print("Dataframe shape:", df.shape)
display(df.head())
# Out:
# Dataframe shape: (2601, 17)
#      x    y  Thermal Conductivity  Lattice Parameter(WPF)  delta_d(SPF-WPF)  \
# 0 -2.5 -2.5              0.668247                5.245110          0.020399
# 1 -2.5 -2.4              0.651635                5.245110          0.020399
# 2 -2.5 -2.3              0.661063                5.244901          0.019877
# 3 -2.5 -2.2              0.594712                5.244901          0.019877
# 4 -2.5 -2.1              0.620809                5.244680          0.019664
#
#    d-spacing(WPF)  Fluorite Size Disorder   Entropy  strain(LMFIT-dspacing)  \
# 0        2.622555                0.103832  3.924187                0.127131
# 1        2.622555                0.103727  3.927794                0.127131
# 2        2.622450                0.103588  3.939862                0.127240
# 3        2.622450                0.103447  3.951859                0.127240
# 4        2.622340                0.103338  3.955091                0.127249
#
#    a111(LMFIT)  a200(LMFIT)  mismatch(LMFIT-lattice parameter)  d111(LMFIT)  \
# 0     5.245331     5.286782                          -0.007902     3.028393
# 1     5.245331     5.286782                          -0.007902     3.028393
# 2     5.245438     5.286226                          -0.007776     3.028455
# 3     5.245438     5.286226                          -0.007776     3.028455
# 4     5.245217     5.285954                          -0.007766     3.028328
#
#    d200(LMFIT)  corr_length  fwhm111(LMFIT)  delta_d/d
# 0     2.643391      2.94866        0.097076   0.007778
# 1     2.643391      2.94866        0.097076   0.007778
# 2     2.643113      2.94866        0.096367   0.007580
# 3     2.643113      2.94866        0.096367   0.007580
# 4     2.642977      2.94866        0.095942   0.007499

# %% [markdown]
# Let's plot them and see how they look

# %% [markdown]
# ### Feature Definitions
#
# 1. **Lattice Parameter (WPF)**
#    Calculated by fitting the **whole XRD spectrum** using **TOPAS**.
#
# 2. **d-spacing (WPF)**
#    Average d-spacing calculated from fitting all peaks.
#
# 3. **Δd (SPF–WPF)**
#    Difference between *d-spacing (200 peak)* (2nd XRD peak) and *d-spacing (WPF)*:
#    $$ \Delta d = d_{WPF} - d_{\text{SPF}} $$
#
# 4. **delta_d/d**
#    Strain calculated from (2) and (3):
#    $$ \frac{\Delta d}{d} = \frac{d_{WPF} - d_{\text{SPF}}}{d_{\text{WPF}}} $$
#
# 5. **a111 (LMFit)**
#    Lattice parameter from fitting the **111 peak** (1st XRD peak) using the **LMFit** package.
#
# 6. **a200 (LMFit)**
#    Lattice parameter from fitting the **200 peak** (2nd XRD peak) using **LMFit**.
#
# 7. **Mismatch (LMFit – lattice parameter)**
#    $$ \text{Mismatch} = \frac{a_{111} - a_{200}}{a_{111}} $$
#
# 8. **d111 (LMFit)**
#    d-spacing of the 111 peak from LMFit.
#
# 9. **d200 (LMFit)**
#    d-spacing of the 200 peak from LMFit.
#
# 10. **Correlation Length**
#     Calculated from AFM images.
#
# 11. **FWHM111 (LMFit)**
#     Full Width at Half Maximum of the **111 peak**.
#
# 12. **Strain (LMFit – d-spacing)**
#     Strain calculated using LMFit d-spacing values:
#     $$ \frac{\Delta d}{d}{LMFIT} = \frac{d_{111} - d_{200}}{d_{111}} $$

# %%
x = df["x"].to_numpy()
y = df["y"].to_numpy()

feature_cols = [c for c in df.columns if c not in ["x", "y"]]

fig, axes = plt.subplots(3, 5, figsize=(20, 12))
axes = axes.flatten()

for ax, col in zip(axes, feature_cols):
    z = pd.to_numeric(df[col], errors="coerce").to_numpy()
    mask = np.isfinite(x) & np.isfinite(y) & np.isfinite(z)

    sc = ax.scatter(x[mask], y[mask], c=z[mask], s=16, cmap="viridis")
    ax.set_title(col, fontsize=15)
    ax.set_aspect("equal", "box")
    ax.set_xticks([]); ax.set_yticks([])

    # colorbar for each subplot
    cbar = plt.colorbar(sc, ax=ax, fraction=0.046, pad=0.04)
    cbar.ax.tick_params(labelsize=8)

# Hide any unused subplots
for ax in axes[len(feature_cols):]:
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- set the column explicitly ---
z_col = "Thermal Conductivity"   # exact match from your df.columns

# --- data ---
x = pd.to_numeric(df["x"], errors="coerce").to_numpy()
y = pd.to_numeric(df["y"], errors="coerce").to_numpy()
z = pd.to_numeric(df[z_col], errors="coerce").to_numpy()
mask = np.isfinite(x) & np.isfinite(y) & np.isfinite(z)

# --- plot ---
plt.figure(figsize=(7, 6))# use them in your scatter
sc = plt.scatter(x[mask], y[mask], c=z[mask], s=18, cmap="viridis", vmin=0, vmax=1)
plt.title(f"Thermal Conductivity [{z_col}]", fontsize=14)
plt.gca().set_aspect("equal", "box")
plt.xticks([]); plt.yticks([])
# plt.gca().invert_yaxis()  # uncomment if your y should increase downward
cbar = plt.colorbar(sc, fraction=0.046, pad=0.04)
cbar.ax.tick_params(labelsize=9)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- set the column explicitly ---
z_col = "Thermal Conductivity"   # exact match from your df.columns

# --- data ---
x = pd.to_numeric(df["x"], errors="coerce").to_numpy()
y = pd.to_numeric(df["y"], errors="coerce").to_numpy()
z = pd.to_numeric(df[z_col], errors="coerce").to_numpy()
mask = np.isfinite(x) & np.isfinite(y) & np.isfinite(z)

# --- plot ---
plt.figure(figsize=(7, 6))# use them in your scatter
sc = plt.scatter(x[mask], y[mask], c=z[mask], s=18, cmap="viridis", vmin=0, vmax=1
)
plt.title(f"Thermal Conductivity [{z_col}]", fontsize=14)
plt.gca().set_aspect("equal", "box")
plt.xticks([]); plt.yticks([])
# plt.gca().invert_yaxis()  # uncomment if your y should increase downward
cbar = plt.colorbar(sc, fraction=0.046, pad=0.04)
cbar.ax.tick_params(labelsize=9)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['x', 'y', 'Thermal Conductivity', 'Lattice Parameter(WPF)',
#        'delta_d(SPF-WPF)', 'd-spacing(WPF)', 'Fluorite Size Disorder',
#        'Entropy', 'strain(LMFIT-dspacing)', 'a111(LMFIT)', 'a200(LMFIT)',
#        'mismatch(LMFIT-lattice parameter)', 'd111(LMFIT)', 'd200(LMFIT)',
#        'corr_length', 'fwhm111(LMFIT)', 'delta_d/d'],
#       dtype='object')

# %% [markdown]
# # How to use this to train in networks?

# %%
features = [
    'a111(LMFIT)', 'mismatch(LMFIT-lattice parameter)',
    'Fluorite Size Disorder', 'Entropy',
    'corr_length',
]
target = 'Thermal Conductivity'

missing = [c for c in features + [target] if c not in df.columns]
if missing:
    raise KeyError(f"These columns are missing in df: {missing}")

# %%
for c in features + [target]:
    df[c] = pd.to_numeric(df[c], errors="coerce")

# 3) drop rows with missing target
df_clean = df.dropna(subset=[target]).copy()

# 4) build matrices
X_raw = df_clean[features].to_numpy(dtype=np.float32) # Input features
y_raw = df_clean[target].to_numpy(dtype=np.float32)[:, None] #Target feature that needs to be predicted
XY    = df_clean[["x","y"]].to_numpy(dtype=np.float32) if set(["x","y"]).issubset(df_clean.columns) else None # can be used to plot predictions back on the grid

# %%
X_train_raw, X_val_raw, y_train, y_val, XY_train, XY_val = train_test_split(
    X_raw, y_raw, XY, test_size=0.2, random_state=42
)
# Use this to split into training and testing dataset

# %% [markdown]
# We split the dataset into training and test sets because we want to test our model on unseen data

# %% [markdown]
# ## Build your network now
#
# Make use of Chatgpt and build your own network to predict one of the features you select

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#data scaling to set mean = 0 and stdev = 1

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_raw)
X_val = scaler.transform(X_val_raw)

# %%
# Build model
model = keras.Sequential([
    layers.Input(shape=(X_train.shape[1],)),   # 5 neurons for the 5 features
    layers.Dense(64, activation='relu'),       # dense layers with ReLU activation
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='linear')       # Linear Output Neuron: Thermal Conductivity
])

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),   # how the model updates its weights
    loss='mse',                                             # what the model tries to minimize
    metrics=['mae']                                         # what to monitor (besides the loss)
)

# %%
# Model training, 200 epochs

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=200,
    batch_size=16,      # subset of data used before updating weights
    verbose=1           # print type
)
# Out:
# Epoch 1/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2394 - mae: 0.3567 - val_loss: 0.0239 - val_mae: 0.1144
# Epoch 2/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0310 - mae: 0.1149 - val_loss: 0.0209 - val_mae: 0.1066
# Epoch 3/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0299 - mae: 0.1115 - val_loss: 0.0215 - val_mae: 0.1091
# Epoch 4/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0299 - mae: 0.1091 - val_loss: 0.0203 - val_mae: 0.1034
# Epoch 5/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0309 - mae: 0.1077 - val_loss: 0.0195 - val_mae: 0.1013
# Epoch 6/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0241 - mae: 0.1054 - val_loss: 0.0195 - val_mae: 0.1024
# Epoch 7/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0372 - mae: 0.1114 - val_loss: 0.0193 - val_mae: 0.0989
# Epoch 8/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0289 - mae: 0.1101 - val_loss: 0.0199 - val_mae: 0.1030
# Epoch 9/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0353 - mae: 0.1063 - val_loss: 0.0188 - val_mae: 0.0992
# Epoch 10/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0306 - mae: 0.0998 - val_loss: 0.0192 - val_mae: 0.1006
# Epoch 11/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0284 - mae: 0.1067 - val_loss: 0.0183 - val_mae: 0.0976
# Epoch 12/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0218 - mae: 0.1011 - val_loss: 0.0225 - val_mae: 0.1123
# Epoch 13/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0326 - mae: 0.1104 - val_loss: 0.0188 - val_mae: 0.0984
# Epoch 14/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0296 - mae: 0.1038 - val_loss: 0.0206 - val_mae: 0.1060
# Epoch 15/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0638 - mae: 0.1169 - val_loss: 0.0187 - val_mae: 0.0984
# Epoch 16/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0448 - mae: 0.1067 - val_loss: 0.0209 - val_mae: 0.1039
# Epoch 17/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0312 - mae: 0.1038 - val_loss: 0.0210 - val_mae: 0.1079
# Epoch 18/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0427 - mae: 0.1061 - val_loss: 0.0192 - val_mae: 0.1001
# Epoch 19/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0789 - mae: 0.1191 - val_loss: 0.0182 - val_mae: 0.0958
# Epoch 20/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0282 - mae: 0.0997 - val_loss: 0.0188 - val_mae: 0.0985
# Epoch 21/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0426 - mae: 0.1076 - val_loss: 0.0188 - val_mae: 0.0980
# Epoch 22/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0260 - mae: 0.1006 - val_loss: 0.0200 - val_mae: 0.1024
# Epoch 23/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0254 - mae: 0.1006 - val_loss: 0.0197 - val_mae: 0.0996
# Epoch 24/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0289 - mae: 0.0989 - val_loss: 0.0221 - val_mae: 0.1098
# Epoch 25/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0867 - mae: 0.1156 - val_loss: 0.0193 - val_mae: 0.0997
# Epoch 26/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0274 - mae: 0.1061 - val_loss: 0.0190 - val_mae: 0.0990
# Epoch 27/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0367 - mae: 0.1079 - val_loss: 0.0193 - val_mae: 0.0998
# Epoch 28/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0262 - mae: 0.1049 - val_loss: 0.0198 - val_mae: 0.1026
# Epoch 29/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0288 - mae: 0.0991 - val_loss: 0.0220 - val_mae: 0.1072
# Epoch 30/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0326 - mae: 0.1097 - val_loss: 0.0185 - val_mae: 0.0959
# Epoch 31/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0260 - mae: 0.1007 - val_loss: 0.0196 - val_mae: 0.1003
# Epoch 32/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0211 - mae: 0.0990 - val_loss: 0.0213 - val_mae: 0.1083
# Epoch 33/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0377 - mae: 0.1049 - val_loss: 0.0194 - val_mae: 0.0992
# Epoch 34/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0527 - mae: 0.1067 - val_loss: 0.0185 - val_mae: 0.0968
# Epoch 35/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0413 - mae: 0.1041 - val_loss: 0.0190 - val_mae: 0.0990
# Epoch 36/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0381 - mae: 0.1085 - val_loss: 0.0189 - val_mae: 0.0977
# Epoch 37/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0382 - mae: 0.0996 - val_loss: 0.0190 - val_mae: 0.0987
# Epoch 38/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0446 - mae: 0.1064 - val_loss: 0.0184 - val_mae: 0.0957
# Epoch 39/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0290 - mae: 0.1033 - val_loss: 0.0199 - val_mae: 0.1004
# Epoch 40/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0282 - mae: 0.0975 - val_loss: 0.0191 - val_mae: 0.0999
# Epoch 41/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0472 - mae: 0.1072 - val_loss: 0.0182 - val_mae: 0.0955
# Epoch 42/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0405 - mae: 0.1061 - val_loss: 0.0191 - val_mae: 0.0991
# Epoch 43/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0839 - mae: 0.1092 - val_loss: 0.0179 - val_mae: 0.0948
# Epoch 44/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0204 - mae: 0.0956 - val_loss: 0.0204 - val_mae: 0.1053
# Epoch 45/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0499 - mae: 0.1044 - val_loss: 0.0182 - val_mae: 0.0959
# Epoch 46/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455 - mae: 0.1056 - val_loss: 0.0191 - val_mae: 0.0989
# Epoch 47/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0264 - mae: 0.0985 - val_loss: 0.0191 - val_mae: 0.0989
# Epoch 48/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0321 - mae: 0.1016 - val_loss: 0.0180 - val_mae: 0.0939
# Epoch 49/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0269 - mae: 0.0945 - val_loss: 0.0188 - val_mae: 0.0984
# Epoch 50/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0304 - mae: 0.1056 - val_loss: 0.0182 - val_mae: 0.0966
# Epoch 51/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0486 - mae: 0.1017 - val_loss: 0.0199 - val_mae: 0.1005
# Epoch 52/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0410 - mae: 0.1027 - val_loss: 0.0189 - val_mae: 0.0982
# Epoch 53/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0249 - mae: 0.0952 - val_loss: 0.0199 - val_mae: 0.1011
# Epoch 54/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0590 - mae: 0.1091 - val_loss: 0.0206 - val_mae: 0.1048
# Epoch 55/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0680 - mae: 0.1134 - val_loss: 0.0194 - val_mae: 0.0980
# Epoch 56/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0244 - mae: 0.0981 - val_loss: 0.0183 - val_mae: 0.0952
# Epoch 57/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0210 - mae: 0.0951 - val_loss: 0.0226 - val_mae: 0.1089
# Epoch 58/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0321 - mae: 0.1041 - val_loss: 0.0187 - val_mae: 0.0981
# Epoch 59/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0258 - mae: 0.0998 - val_loss: 0.0191 - val_mae: 0.0973
# Epoch 60/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1069 - val_loss: 0.0196 - val_mae: 0.0997
# Epoch 61/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0232 - mae: 0.0947 - val_loss: 0.0220 - val_mae: 0.1096
# Epoch 62/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0319 - mae: 0.1006 - val_loss: 0.0192 - val_mae: 0.0986
# Epoch 63/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0245 - mae: 0.0953 - val_loss: 0.0185 - val_mae: 0.0957
# Epoch 64/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0200 - mae: 0.0911 - val_loss: 0.0209 - val_mae: 0.1024
# Epoch 65/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0378 - mae: 0.1006 - val_loss: 0.0183 - val_mae: 0.0950
# Epoch 66/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0489 - mae: 0.0989 - val_loss: 0.0188 - val_mae: 0.0978
# Epoch 67/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0209 - mae: 0.0949 - val_loss: 0.0191 - val_mae: 0.0994
# Epoch 68/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0350 - mae: 0.1001 - val_loss: 0.0181 - val_mae: 0.0938
# Epoch 69/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0227 - mae: 0.0975 - val_loss: 0.0192 - val_mae: 0.0973
# Epoch 70/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0233 - mae: 0.0956 - val_loss: 0.0189 - val_mae: 0.0972
# Epoch 71/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0333 - mae: 0.0988 - val_loss: 0.0245 - val_mae: 0.1161
# Epoch 72/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0660 - mae: 0.1092 - val_loss: 0.0187 - val_mae: 0.0957
# Epoch 73/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0300 - mae: 0.0980 - val_loss: 0.0191 - val_mae: 0.0977
# Epoch 74/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0226 - mae: 0.0963 - val_loss: 0.0191 - val_mae: 0.0989
# Epoch 75/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0278 - mae: 0.0985 - val_loss: 0.0185 - val_mae: 0.0954
# Epoch 76/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0223 - mae: 0.0959 - val_loss: 0.0207 - val_mae: 0.0996
# Epoch 77/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194 - mae: 0.0949 - val_loss: 0.0249 - val_mae: 0.1159
# Epoch 78/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0428 - mae: 0.1051 - val_loss: 0.0191 - val_mae: 0.0967
# Epoch 79/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0217 - mae: 0.0937 - val_loss: 0.0200 - val_mae: 0.1023
# Epoch 80/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0402 - mae: 0.1001 - val_loss: 0.0187 - val_mae: 0.0971
# Epoch 81/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0441 - mae: 0.1028 - val_loss: 0.0188 - val_mae: 0.0969
# Epoch 82/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0304 - mae: 0.1014 - val_loss: 0.0182 - val_mae: 0.0947
# Epoch 83/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0304 - mae: 0.0957 - val_loss: 0.0183 - val_mae: 0.0965
# Epoch 84/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0235 - mae: 0.0956 - val_loss: 0.0195 - val_mae: 0.1007
# Epoch 85/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0266 - mae: 0.0953 - val_loss: 0.0199 - val_mae: 0.0967
# Epoch 86/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0240 - mae: 0.0938 - val_loss: 0.0175 - val_mae: 0.0936
# Epoch 87/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0264 - mae: 0.0965 - val_loss: 0.0175 - val_mae: 0.0931
# Epoch 88/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0538 - mae: 0.1061 - val_loss: 0.0173 - val_mae: 0.0909
# Epoch 89/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0439 - mae: 0.0951 - val_loss: 0.0196 - val_mae: 0.0981
# Epoch 90/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0374 - mae: 0.1013 - val_loss: 0.0175 - val_mae: 0.0933
# Epoch 91/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0379 - mae: 0.0979 - val_loss: 0.0188 - val_mae: 0.0961
# Epoch 92/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0400 - mae: 0.0986 - val_loss: 0.0185 - val_mae: 0.0936
# Epoch 93/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0407 - mae: 0.0996 - val_loss: 0.0213 - val_mae: 0.1062
# Epoch 94/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0294 - mae: 0.0970 - val_loss: 0.0199 - val_mae: 0.0973
# Epoch 95/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0668 - mae: 0.1046 - val_loss: 0.0192 - val_mae: 0.0960
# Epoch 96/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189 - mae: 0.0918 - val_loss: 0.0212 - val_mae: 0.1066
# Epoch 97/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194 - mae: 0.0947 - val_loss: 0.0195 - val_mae: 0.1003
# Epoch 98/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0372 - mae: 0.0975 - val_loss: 0.0202 - val_mae: 0.0984
# Epoch 99/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0263 - mae: 0.0977 - val_loss: 0.0197 - val_mae: 0.0984
# Epoch 100/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mae: 0.0984 - val_loss: 0.0199 - val_mae: 0.0987
# Epoch 101/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0205 - mae: 0.0907 - val_loss: 0.0194 - val_mae: 0.0968
# Epoch 102/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0330 - mae: 0.1035 - val_loss: 0.0196 - val_mae: 0.0971
# Epoch 103/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0227 - mae: 0.0911 - val_loss: 0.0177 - val_mae: 0.0931
# Epoch 104/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - mae: 0.0952 - val_loss: 0.0199 - val_mae: 0.1004
# Epoch 105/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0388 - mae: 0.0980 - val_loss: 0.0184 - val_mae: 0.0943
# Epoch 106/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0287 - mae: 0.0979 - val_loss: 0.0195 - val_mae: 0.0998
# Epoch 107/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0371 - mae: 0.1005 - val_loss: 0.0186 - val_mae: 0.0943
# Epoch 108/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0213 - mae: 0.0915 - val_loss: 0.0186 - val_mae: 0.0963
# Epoch 109/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0299 - mae: 0.0973 - val_loss: 0.0201 - val_mae: 0.1021
# Epoch 110/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0248 - mae: 0.0957 - val_loss: 0.0191 - val_mae: 0.0976
# Epoch 111/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0826 - mae: 0.1079 - val_loss: 0.0199 - val_mae: 0.0994
# Epoch 112/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0320 - mae: 0.0947 - val_loss: 0.0203 - val_mae: 0.0967
# Epoch 113/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0549 - mae: 0.1053 - val_loss: 0.0171 - val_mae: 0.0923
# Epoch 114/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0396 - mae: 0.0947 - val_loss: 0.0185 - val_mae: 0.0947
# Epoch 115/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0316 - mae: 0.0946 - val_loss: 0.0198 - val_mae: 0.0992
# Epoch 116/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0359 - mae: 0.0989 - val_loss: 0.0195 - val_mae: 0.0961
# Epoch 117/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0518 - mae: 0.1032 - val_loss: 0.0181 - val_mae: 0.0922
# Epoch 118/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0314 - mae: 0.0982 - val_loss: 0.0190 - val_mae: 0.0940
# Epoch 119/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0313 - mae: 0.0950 - val_loss: 0.0181 - val_mae: 0.0938
# Epoch 120/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - mae: 0.0912 - val_loss: 0.0197 - val_mae: 0.1011
# Epoch 121/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0464 - mae: 0.0988 - val_loss: 0.0180 - val_mae: 0.0942
# Epoch 122/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0301 - mae: 0.0924 - val_loss: 0.0189 - val_mae: 0.0962
# Epoch 123/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - mae: 0.0905 - val_loss: 0.0195 - val_mae: 0.0978
# Epoch 124/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0397 - mae: 0.0961 - val_loss: 0.0182 - val_mae: 0.0935
# Epoch 125/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194 - mae: 0.0898 - val_loss: 0.0201 - val_mae: 0.1012
# Epoch 126/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0199 - mae: 0.0935 - val_loss: 0.0234 - val_mae: 0.1104
# Epoch 127/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0334 - mae: 0.0986 - val_loss: 0.0178 - val_mae: 0.0922
# Epoch 128/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0493 - mae: 0.1043 - val_loss: 0.0207 - val_mae: 0.0980
# Epoch 129/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0242 - mae: 0.0945 - val_loss: 0.0191 - val_mae: 0.0965
# Epoch 130/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - mae: 0.0930 - val_loss: 0.0195 - val_mae: 0.0973
# Epoch 131/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0236 - mae: 0.0890 - val_loss: 0.0201 - val_mae: 0.0989
# Epoch 132/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0234 - mae: 0.0947 - val_loss: 0.0198 - val_mae: 0.0981
# Epoch 133/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - mae: 0.0941 - val_loss: 0.0180 - val_mae: 0.0947
# Epoch 134/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0250 - mae: 0.0930 - val_loss: 0.0192 - val_mae: 0.0941
# Epoch 135/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0219 - mae: 0.0931 - val_loss: 0.0193 - val_mae: 0.0961
# Epoch 136/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0485 - mae: 0.0981 - val_loss: 0.0174 - val_mae: 0.0921
# Epoch 137/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0370 - mae: 0.0975 - val_loss: 0.0183 - val_mae: 0.0942
# Epoch 138/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0220 - mae: 0.0950 - val_loss: 0.0189 - val_mae: 0.0961
# Epoch 139/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0259 - mae: 0.0933 - val_loss: 0.0196 - val_mae: 0.0971
# Epoch 140/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - mae: 0.0894 - val_loss: 0.0216 - val_mae: 0.1041
# Epoch 141/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0282 - mae: 0.0927 - val_loss: 0.0199 - val_mae: 0.0973
# Epoch 142/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0284 - mae: 0.0918 - val_loss: 0.0186 - val_mae: 0.0936
# Epoch 143/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0268 - mae: 0.0928 - val_loss: 0.0182 - val_mae: 0.0955
# Epoch 144/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0402 - mae: 0.0962 - val_loss: 0.0196 - val_mae: 0.0945
# Epoch 145/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0382 - mae: 0.0950 - val_loss: 0.0208 - val_mae: 0.1010
# Epoch 146/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0375 - mae: 0.0976 - val_loss: 0.0204 - val_mae: 0.0956
# Epoch 147/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0373 - mae: 0.0937 - val_loss: 0.0181 - val_mae: 0.0946
# Epoch 148/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0220 - mae: 0.0947 - val_loss: 0.0198 - val_mae: 0.0983
# Epoch 149/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0237 - mae: 0.0940 - val_loss: 0.0205 - val_mae: 0.0985
# Epoch 150/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0364 - mae: 0.0961 - val_loss: 0.0182 - val_mae: 0.0926
# Epoch 151/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193 - mae: 0.0890 - val_loss: 0.0211 - val_mae: 0.1051
# Epoch 152/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - mae: 0.0908 - val_loss: 0.0194 - val_mae: 0.0985
# Epoch 153/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0235 - mae: 0.0932 - val_loss: 0.0190 - val_mae: 0.0939
# Epoch 154/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166 - mae: 0.0842 - val_loss: 0.0230 - val_mae: 0.1069
# Epoch 155/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0507 - mae: 0.1015 - val_loss: 0.0185 - val_mae: 0.0941
# Epoch 156/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174 - mae: 0.0873 - val_loss: 0.0209 - val_mae: 0.0998
# Epoch 157/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0339 - mae: 0.0993 - val_loss: 0.0184 - val_mae: 0.0961
# Epoch 158/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0156 - mae: 0.0882 - val_loss: 0.0209 - val_mae: 0.1038
# Epoch 159/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0279 - mae: 0.0985 - val_loss: 0.0184 - val_mae: 0.0930
# Epoch 160/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - mae: 0.0896 - val_loss: 0.0200 - val_mae: 0.0982
# Epoch 161/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0325 - mae: 0.0965 - val_loss: 0.0195 - val_mae: 0.0978
# Epoch 162/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0336 - mae: 0.0974 - val_loss: 0.0212 - val_mae: 0.1003
# Epoch 163/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0273 - mae: 0.0931 - val_loss: 0.0192 - val_mae: 0.0934
# Epoch 164/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0392 - mae: 0.0966 - val_loss: 0.0191 - val_mae: 0.0949
# Epoch 165/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0462 - mae: 0.1021 - val_loss: 0.0208 - val_mae: 0.0965
# Epoch 166/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0291 - mae: 0.0918 - val_loss: 0.0202 - val_mae: 0.0963
# Epoch 167/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0207 - mae: 0.0907 - val_loss: 0.0200 - val_mae: 0.1003
# Epoch 168/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0642 - mae: 0.1069 - val_loss: 0.0206 - val_mae: 0.0971
# Epoch 169/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0215 - mae: 0.0909 - val_loss: 0.0215 - val_mae: 0.1011
# Epoch 170/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0233 - mae: 0.0976 - val_loss: 0.0208 - val_mae: 0.0995
# Epoch 171/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0239 - mae: 0.0919 - val_loss: 0.0187 - val_mae: 0.0935
# Epoch 172/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0439 - mae: 0.0982 - val_loss: 0.0191 - val_mae: 0.0952
# Epoch 173/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0222 - mae: 0.0862 - val_loss: 0.0187 - val_mae: 0.0959
# Epoch 174/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0672 - mae: 0.1029 - val_loss: 0.0208 - val_mae: 0.0979
# Epoch 175/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0337 - mae: 0.0981 - val_loss: 0.0192 - val_mae: 0.0969
# Epoch 176/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0678 - mae: 0.1015 - val_loss: 0.0208 - val_mae: 0.0970
# Epoch 177/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0252 - mae: 0.0931 - val_loss: 0.0178 - val_mae: 0.0919
# Epoch 178/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - mae: 0.0880 - val_loss: 0.0222 - val_mae: 0.1069
# Epoch 179/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - mae: 0.0909 - val_loss: 0.0205 - val_mae: 0.0968
# Epoch 180/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0295 - mae: 0.0969 - val_loss: 0.0180 - val_mae: 0.0951
# Epoch 181/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0285 - mae: 0.0908 - val_loss: 0.0188 - val_mae: 0.0962
# Epoch 182/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0259 - mae: 0.0930 - val_loss: 0.0206 - val_mae: 0.0965
# Epoch 183/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0371 - mae: 0.0914 - val_loss: 0.0209 - val_mae: 0.0992
# Epoch 184/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0319 - mae: 0.0936 - val_loss: 0.0203 - val_mae: 0.0953
# Epoch 185/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0277 - mae: 0.0922 - val_loss: 0.0180 - val_mae: 0.0937
# Epoch 186/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0198 - mae: 0.0907 - val_loss: 0.0195 - val_mae: 0.0958
# Epoch 187/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0239 - mae: 0.0883 - val_loss: 0.0188 - val_mae: 0.0946
# Epoch 188/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0291 - mae: 0.0912 - val_loss: 0.0186 - val_mae: 0.0960
# Epoch 189/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0381 - mae: 0.0982 - val_loss: 0.0179 - val_mae: 0.0925
# Epoch 190/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0310 - mae: 0.0930 - val_loss: 0.0189 - val_mae: 0.0967
# Epoch 191/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.0924 - val_loss: 0.0209 - val_mae: 0.0979
# Epoch 192/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0277 - mae: 0.0951 - val_loss: 0.0185 - val_mae: 0.0940
# Epoch 193/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163 - mae: 0.0871 - val_loss: 0.0188 - val_mae: 0.0939
# Epoch 194/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192 - mae: 0.0886 - val_loss: 0.0208 - val_mae: 0.1004
# Epoch 195/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0262 - mae: 0.0940 - val_loss: 0.0196 - val_mae: 0.0954
# Epoch 196/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450 - mae: 0.0976 - val_loss: 0.0190 - val_mae: 0.0986
# Epoch 197/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0263 - mae: 0.0910 - val_loss: 0.0197 - val_mae: 0.0970
# Epoch 198/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0195 - mae: 0.0933 - val_loss: 0.0203 - val_mae: 0.1001
# Epoch 199/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0340 - mae: 0.0921 - val_loss: 0.0196 - val_mae: 0.0962
# Epoch 200/200
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0387 - mae: 0.0942 - val_loss: 0.0209 - val_mae: 0.0991

# %%
# Evaluate model performance

val_loss, val_mae = model.evaluate(X_val, y_val, verbose=0)
print(f"Validation MAE: {val_mae:.4f}")
# Out:
# Validation MAE: 0.0991

# %%
# Make predictions

y_pred = model.predict(X_val)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
import matplotlib.pyplot as plt

plt.scatter(y_val, y_pred, alpha=0.7)
plt.xlabel("True Thermal Conductivity")
plt.ylabel("Predicted Thermal Conductivity")
plt.title("Model Predictions vs True Values")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Extract coordinates
x = XY_val[:, 0]
y = XY_val[:, 1]

# Flatten y arrays
y_true = y_val.flatten()
y_pred_flat = y_pred.flatten()

# Compute absolute prediction error
error = np.abs(y_pred_flat - y_true)

# Create figure with 3 panels
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# --- True values ---
sc1 = axes[0].scatter(x, y, c=y_true, cmap='viridis', s=60, edgecolor='k', alpha=0.85)
axes[0].set_title('True Thermal Conductivity')
axes[0].set_xlabel('X Position')
axes[0].set_ylabel('Y Position')
axes[0].axis('equal')
plt.colorbar(sc1, ax=axes[0])

# --- Predicted values ---
sc2 = axes[1].scatter(x, y, c=y_pred_flat, cmap='viridis', s=60, edgecolor='k', alpha=0.85)
axes[1].set_title('Predicted Thermal Conductivity')
axes[1].set_xlabel('X Position')
axes[1].set_ylabel('Y Position')
axes[1].axis('equal')
plt.colorbar(sc2, ax=axes[1])

# --- Error map ---
sc3 = axes[2].scatter(x, y, c=error, cmap='inferno', s=60, edgecolor='k', alpha=0.85)
axes[2].set_title('Prediction Error |y_pred - y_true|')
axes[2].set_xlabel('X Position')
axes[2].set_ylabel('Y Position')
axes[2].axis('equal')
plt.colorbar(sc3, ax=axes[2], label='Absolute Error')

plt.tight_layout()
plt.show()
